# %% [markdown]
# # 随机梯度下降法

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 10000

x = np.random.normal(size = m)
X = x.reshape(-1, 1)
y = 4.*x + 3. + np.random.normal(0, 3, size=m)

# %%
history_theta = []
def J(theta, X_b, y):
    try:
        return np.sum((y - X_b.dot(theta)) ** 2.) / len(y)
    except:
        return float('inf')

def dJ(theta, X_b, y):
    return X_b.T.dot(X_b.dot(theta) - y) * 2. / len(y)

def gradient_descent(X_b, y, initial_theta, eta, n_iters=1e4, epsilon=1e-8):
    theta = initial_theta
    cur_iter = 0
    history_theta.append(theta)

    while cur_iter < n_iters:
        gradient = dJ(theta, X_b, y)
        last_theta = theta
        theta = theta - eta * gradient
        history_theta.append(theta)

        if(abs(J(theta, X_b, y) - J(last_theta, X_b, y)) < epsilon):
            break
        cur_iter += 1
    return theta

# %%
# %%time
X_b = np.hstack([np.ones((len(X), 1)), X])
initial_theta = np.zeros(X_b.shape[1])
eta = 0.01

theta = gradient_descent(X_b, y, initial_theta, eta)
# Out:
# CPU times: user 109 ms, sys: 29 ms, total: 138 ms
# Wall time: 107 ms

# %%
theta
# Out:
# array([3.01918081, 4.03207167])

# %%
history_theta
# Out:
# [array([0., 0.]),
#  array([0.06057737, 0.08163455]),
#  array([0.11993939, 0.16161648]),
#  array([0.17811045, 0.23997924]),
#  array([0.23511445, 0.31675562]),
#  array([0.29097479, 0.39197773]),
#  array([0.34571442, 0.46567703]),
#  array([0.39935583, 0.53788435]),
#  array([0.45192105, 0.60862989]),
#  array([0.50343168, 0.67794326]),
#  array([0.55390886, 0.74585343]),
#  array([0.60337335, 0.81238881]),
#  array([0.65184545, 0.87757724]),
#  array([0.69934507, 0.94144599]),
#  array([0.74589173, 1.00402176]),
#  array([0.79150454, 1.06533074]),
#  array([0.83620224, 1.12539857]),
#  array([0.8800032 , 1.18425037]),
#  array([0.92292539, 1.24191076]),
#  array([0.96498646, 1.29840386]),
#  array([1.00620368, 1.35375331]),
#  array([1.04659398, 1.40798224]),
#  array([1.08617395, 1.46111336]),
#  array([1.12495985, 1.51316887]),
#  array([1.16296761, 1.56417056]),
#  array([1.20021283, 1.61413975]),
#  array([1.23671083, 1.66309736]),
#  array([1.27247659, 1.71106386]),
#  array([1.30752481, 1.7580593 ]),
#  array([1.34186987, 1.80410336]),
#  array([1.37552589, 1.84921529]),
#  array([1.40850669, 1.89341396]),
#  array([1.44082581, 1.93671786]),
#  array([1.47249654, 1.9791451 ]),
#  array([1.50353188, 2.02071344]),
#  array([1.53394458, 2.06144024]),
#  array([1.56374713, 2.10134256]),
#  array([1.59295177, 2.14043709]),
#  array([1.6215705 , 2.17874017]),
#  array([1.64961507, 2.21626783]),
#  array([1.677097  , 2.25303577]),
#  array([1.70402759, 2.28905936]),
#  array([1.73041788, 2.32435368]),
#  array([1.75627873, 2.35893349]),
#  array([1.78162076, 2.39281325]),
#  array([1.80645436, 2.42600714]),
#  array([1.83078975, 2.45852903]),
#  array([1.85463692, 2.49039254]),
#  array([1.87800566, 2.52161099]),
#  array([1.90090557, 2.55219745]),
#  array([1.92334606, 2.58216469]),
#  array([1.94533635, 2.61152527]),
#  array([1.96688547, 2.64029146]),
#  array([1.98800226, 2.66847529]),
#  array([2.00869541, 2.69608856]),
#  array([2.02897341, 2.72314281]),
#  array([2.04884459, 2.74964937]),
#  array([2.06831711, 2.77561931]),
#  array([2.08739897, 2.8010635 ]),
#  array([2.10609802, 2.82599259]),
#  array([2.12442192, 2.85041701]),
#  array([2.14237821, 2.87434696]),
#  array([2.15997425, 2.89779246]),
#  array([2.17721729, 2.92076332]),
#  array([2.1941144 , 2.94326915]),
#  array([2.21067251, 2.96531936]),
#  array([2.22689844, 2.98692317]),
#  array([2.24279885, 3.00808962]),
#  array([2.25838026, 3.02882757]),
#  array([2.27364908, 3.04914568]),
#  array([2.28861157, 3.06905247]),
#  array([2.30327389, 3.08855625]),
#  array([2.31764206, 3.10766519]),
#  array([2.33172197, 3.12638727]),
#  array([2.34551942, 3.14473033]),
#  array([2.35904006, 3.16270205]),
#  array([2.37228945, 3.18030994]),
#  array([2.38527304, 3.19756136]),
#  array([2.39799615, 3.21446353]),
#  array([2.41046401, 3.23102352]),
#  array([2.42268174, 3.24724827]),
#  array([2.43465437, 3.26314455]),
#  array([2.4463868 , 3.27871901]),
#  array([2.45788386, 3.29397818]),
#  array([2.46915027, 3.30892843]),
#  array([2.48019065, 3.32357602]),
#  array([2.49100954, 3.33792707]),
#  array([2.50161139, 3.35198759]),
#  array([2.51200055, 3.36576346]),
#  array([2.52218128, 3.37926044]),
#  array([2.53215777, 3.39248418]),
#  array([2.54193412, 3.40544021]),
#  array([2.55151433, 3.41813395]),
#  array([2.56090235, 3.4305707 ]),
#  array([2.57010204, 3.44275568]),
#  array([2.57911716, 3.45469398]),
#  array([2.58795142, 3.46639059]),
#  array([2.59660845, 3.4778504 ]),
#  array([2.60509181, 3.48907822]),
#  array([2.61340498, 3.50007873]),
#  array([2.62155138, 3.51085653]),
#  array([2.62953434, 3.52141615]),
#  array([2.63735715, 3.53176198]),
#  array([2.64502303, 3.54189837]),
#  array([2.65253512, 3.55182955]),
#  array([2.6598965 , 3.56155967]),
#  array([2.6671102 , 3.57109281]),
#  array([2.67417919, 3.58043296]),
#  array([2.68110636, 3.58958401]),
#  array([2.68789456, 3.5985498 ]),
#  array([2.69454658, 3.60733408]),
#  array([2.70106515, 3.61594053]),
#  array([2.70745295, 3.62437274]),
#  array([2.7137126 , 3.63263424]),
#  array([2.71984668, 3.64072849]),
#  array([2.72585769, 3.64865887]),
#  array([2.73174812, 3.6564287 ]),
#  array([2.73752037, 3.66404123]),
#  array([2.74317683, 3.67149965]),
#  array([2.74871981, 3.67880707]),
#  array([2.75415159, 3.68596656]),
#  array([2.7594744, 3.6929811]),
#  array([2.76469043, 3.69985364]),
#  array([2.76980182, 3.70658704]),
#  array([2.77481067, 3.71318412]),
#  array([2.77971903, 3.71964764]),
#  array([2.78452893, 3.72598032]),
#  array([2.78924233, 3.73218478]),
#  array([2.79386118, 3.73826364]),
#  array([2.79838736, 3.74421943]),
#  array([2.80282275, 3.75005465]),
#  array([2.80716915, 3.75577174]),
#  array([2.81142837, 3.76137308]),
#  array([2.81560213, 3.76686102]),
#  array([2.81969217, 3.77223786]),
#  array([2.82370016, 3.77750585]),
#  array([2.82762774, 3.78266718]),
#  array([2.83147653, 3.78772402]),
#  array([2.8352481 , 3.79267849]),
#  array([2.83894402, 3.79753266]),
#  array([2.84256579, 3.80228855]),
#  array([2.84611491, 3.80694816]),
#  array([2.84959282, 3.81151343]),
#  array([2.85300097, 3.81598629]),
#  array([2.85634074, 3.82036858]),
#  array([2.85961351, 3.82466216]),
#  array([2.86282063, 3.82886882]),
#  array([2.86596341, 3.83299031]),
#  array([2.86904315, 3.83702836]),
#  array([2.8720611 , 3.84098466]),
#  array([2.87501851, 3.84486086]),
#  array([2.87791659, 3.84865859]),
#  array([2.88075653, 3.85237944]),
#  array([2.8835395 , 3.85602495]),
#  array([2.88626664, 3.85959667]),
#  array([2.88893907, 3.86309607]),
#  array([2.89155789, 3.86652463]),
#  array([2.89412417, 3.86988377]),
#  array([2.89663897, 3.87317491]),
#  array([2.89910333, 3.87639942]),
#  array([2.90151824, 3.87955865]),
#  array([2.90388471, 3.88265392]),
#  array([2.90620371, 3.88568652]),
#  array([2.90847618, 3.88865773]),
#  array([2.91070307, 3.89156879]),
#  array([2.91288529, 3.89442091]),
#  array([2.91502372, 3.89721529]),
#  array([2.91711926, 3.8999531 ]),
#  array([2.91917276, 3.90263548]),
#  array([2.92118507, 3.90526356]),
#  array([2.92315701, 3.90783842]),
#  array([2.92508938, 3.91036116]),
#  array([2.926983  , 3.91283283]),
#  array([2.92883862, 3.91525446]),
#  array([2.93065703, 3.91762706]),
#  array([2.93243895, 3.91995163]),
#  array([2.93418512, 3.92222913]),
#  array([2.93589627, 3.92446053]),
#  array([2.93757309, 3.92664675]),
#  array([2.93921627, 3.92878871]),
#  array([2.94082649, 3.93088731]),
#  array([2.94240441, 3.93294342]),
#  array([2.94395067, 3.9349579 ]),
#  array([2.94546591, 3.9369316 ]),
#  array([2.94695076, 3.93886534]),
#  array([2.94840582, 3.94075993]),
#  array([2.94983169, 3.94261617]),
#  array([2.95122896, 3.94443482]),
#  array([2.95259819, 3.94621666]),
#  array([2.95393996, 3.94796242]),
#  array([2.95525482, 3.94967284]),
#  array([2.95654329, 3.95134863]),
#  array([2.95780592, 3.95299049]),
#  array([2.95904322, 3.95459912]),
#  array([2.9602557 , 3.95617517]),
#  array([2.96144385, 3.95771932]),
#  array([2.96260817, 3.95923221]),
#  array([2.96374914, 3.96071447]),
#  array([2.96486721, 3.96216671]),
#  array([2.96596286, 3.96358956]),
#  array([2.96703653, 3.9649836 ]),
#  array([2.96808866, 3.96634942]),
#  array([2.96911968, 3.96768759]),
#  array([2.97013002, 3.96899866]),
#  array([2.97112009, 3.97028319]),
#  array([2.9720903 , 3.97154172]),
#  array([2.97304105, 3.97277477]),
#  array([2.97397273, 3.97398285]),
#  array([2.97488571, 3.97516647]),
#  array([2.97578038, 3.97632613]),
#  array([2.97665711, 3.97746232]),
#  array([2.97751625, 3.9785755 ]),
#  array([2.97835815, 3.97966614]),
#  array([2.97918316, 3.98073471]),
#  array([2.97999162, 3.98178164]),
#  array([2.98078387, 3.98280737]),
#  array([2.98156022, 3.98381234]),
#  array([2.982321  , 3.98479696]),
#  array([2.98306652, 3.98576165]),
#  array([2.98379708, 3.9867068 ]),
#  array([2.98451299, 3.98763282]),
#  array([2.98521453, 3.9885401 ]),
#  array([2.98590201, 3.989429  ]),
#  array([2.98657569, 3.99029991]),
#  array([2.98723586, 3.99115319]),
#  array([2.98788278, 3.99198919]),
#  array([2.98851673, 3.99280827]),
#  array([2.98913796, 3.99361076]),
#  array([2.98974673, 3.99439701]),
#  array([2.99034328, 3.99516734]),
#  array([2.99092787, 3.99592207]),
#  array([2.99150074, 3.99666152]),
#  array([2.99206211, 3.997386  ]),
#  array([2.99261222, 3.99809582]),
#  array([2.99315129, 3.99879126]),
#  array([2.99367955, 3.99947263]),
#  array([2.99419721, 4.0001402 ]),
#  array([2.99470449, 4.00079425]),
#  array([2.9952016 , 4.00143506]),
#  array([2.99568873, 4.0020629 ]),
#  array([2.99616609, 4.00267803]),
#  array([2.99663387, 4.0032807 ]),
#  array([2.99709227, 4.00387118]),
#  array([2.99754148, 4.00444969]),
#  array([2.99798167, 4.0050165 ]),
#  array([2.99841303, 4.00557183]),
#  array([2.99883574, 4.00611592]),
#  array([2.99924997, 4.00664899]),
#  array([2.9996559 , 4.00717127]),
#  array([3.00005367, 4.00768297]),
#  array([3.00044347, 4.00818432]),
#  array([3.00082545, 4.00867551]),
#  array([3.00119977, 4.00915676]),
#  array([3.00156658, 4.00962827]),
#  array([3.00192603, 4.01009023]),
#  array([3.00227827, 4.01054284]),
#  array([3.00262344, 4.01098629]),
#  array([3.00296169, 4.01142075]),
#  array([3.00329316, 4.01184642]),
#  array([3.00361797, 4.01226348]),
#  array([3.00393627, 4.01267209]),
#  array([3.00424819, 4.01307242]),
#  array([3.00455385, 4.01346465]),
#  array([3.00485337, 4.01384894]),
#  array([3.00514689, 4.01422545]),
#  array([3.00543452, 4.01459434]),
#  array([3.00571638, 4.01495576]),
#  array([3.00599259, 4.01530986]),
#  array([3.00626326, 4.0156568 ]),
#  array([3.00652849, 4.0159967 ]),
#  array([3.00678841, 4.01632973]),
#  array([3.00704311, 4.01665602]),
#  array([3.0072927 , 4.01697569]),
#  array([3.00753729, 4.0172889 ]),
#  array([3.00777697, 4.01759577]),
#  array([3.00801184, 4.01789642]),
#  array([3.008242  , 4.01819098]),
#  array([3.00846754, 4.01847959]),
#  array([3.00868856, 4.01876234]),
#  array([3.00890515, 4.01903938]),
#  array([3.00911739, 4.0193108 ]),
#  array([3.00932537, 4.01957673]),
#  array([3.00952919, 4.01983728]),
#  array([3.00972891, 4.02009255]),
#  array([3.00992463, 4.02034265]),
#  array([3.01011642, 4.02058769]),
#  array([3.01030436, 4.02082777]),
#  array([3.01048854, 4.02106299]),
#  array([3.01066901, 4.02129344]),
#  array([3.01084587, 4.02151923]),
#  array([3.01101918, 4.02174045]),
#  array([3.01118902, 4.02195719]),
#  array([3.01135545, 4.02216954]),
#  array([3.01151854, 4.02237759]),
#  array([3.01167835, 4.02258143]),
#  array([3.01183497, 4.02278115]),
#  array([3.01198844, 4.02297681]),
#  array([3.01213883, 4.02316852]),
#  array([3.01228621, 4.02335635]),
#  array([3.01243062, 4.02354037]),
#  array([3.01257215, 4.02372067]),
#  array([3.01271083, 4.02389732]),
#  array([3.01284673, 4.02407039]),
#  array([3.01297991, 4.02423996]),
#  array([3.01311041, 4.02440609]),
#  array([3.0132383 , 4.02456886]),
#  array([3.01336362, 4.02472834]),
#  array([3.01348643, 4.02488458]),
#  array([3.01360677, 4.02503766]),
#  array([3.0137247 , 4.02518765]),
#  array([3.01384026, 4.0253346 ]),
#  array([3.01395351, 4.02547857]),
#  array([3.01406448, 4.02561962]),
#  array([3.01417323, 4.02575783]),
#  array([3.0142798 , 4.02589323]),
#  array([3.01438423, 4.02602589]),
#  array([3.01448656, 4.02615587]),
#  array([3.01458684, 4.02628321]),
#  array([3.01468511, 4.02640798]),
#  array([3.01478141, 4.02653022]),
#  array([3.01487578, 4.02664998]),
#  array([3.01496825, 4.02676732]),
#  array([3.01505887, 4.02688229]),
#  array([3.01514768, 4.02699492]),
#  array([3.0152347 , 4.02710528]),
#  array([3.01531997, 4.0272134 ]),
#  array([3.01540354, 4.02731933]),
#  array([3.01548542, 4.02742312]),
#  array([3.01556567, 4.02752481]),
#  array([3.0156443 , 4.02762444]),
#  array([3.01572136, 4.02772205]),
#  array([3.01579688, 4.02781768]),
#  array([3.01587087, 4.02791138]),
#  array([3.01594339, 4.02800318]),
#  array([3.01601445, 4.02809313]),
#  array([3.01608408, 4.02818125]),
#  array([3.01615232, 4.02826759]),
#  array([3.01621919, 4.02835218]),
#  array([3.01628471, 4.02843505]),
#  array([3.01634893, 4.02851625]),
#  array([3.01641185, 4.02859581]),
#  array([3.01647351, 4.02867375]),
#  array([3.01653394, 4.02875012]),
#  array([3.01659315, 4.02882494]),
#  array([3.01665118, 4.02889824]),
#  array([3.01670804, 4.02897007]),
#  array([3.01676376, 4.02904043]),
#  array([3.01681836, 4.02910937]),
#  array([3.01687187, 4.02917692]),
#  array([3.01692431, 4.0292431 ]),
#  array([3.01697569, 4.02930794]),
#  array([3.01702604, 4.02937147]),
#  array([3.01707539, 4.02943371]),
#  array([3.01712374, 4.02949469]),
#  array([3.01717112, 4.02955443]),
#  array([3.01721755, 4.02961297]),
#  array([3.01726306, 4.02967032]),
#  array([3.01730764, 4.02972651]),
#  array([3.01735134, 4.02978156]),
#  array([3.01739415, 4.0298355 ]),
#  array([3.01743611, 4.02988834]),
#  array([3.01747723, 4.02994012]),
#  array([3.01751752, 4.02999084]),
#  array([3.01755701, 4.03004054]),
#  array([3.0175957 , 4.03008924]),
#  array([3.01763361, 4.03013694]),
#  array([3.01767077, 4.03018369]),
#  array([3.01770718, 4.03022948]),
#  array([3.01774286, 4.03027435]),
#  array([3.01777782, 4.03031831]),
#  array([3.01781209, 4.03036138]),
#  array([3.01784566, 4.03040358]),
#  array([3.01787856, 4.03044492]),
#  array([3.01791081, 4.03048543]),
#  array([3.0179424 , 4.03052511]),
#  array([3.01797336, 4.030564  ]),
#  array([3.0180037 , 4.03060209]),
#  array([3.01803344, 4.03063942]),
#  array([3.01806257, 4.03067598]),
#  array([3.01809112, 4.03071181]),
#  array([3.0181191 , 4.03074692]),
#  array([3.01814652, 4.03078131]),
#  array([3.01817339, 4.030815  ]),
#  array([3.01819971, 4.03084802]),
#  array([3.01822552, 4.03088036]),
#  array([3.0182508 , 4.03091205]),
#  array([3.01827557, 4.0309431 ]),
#  array([3.01829985, 4.03097352]),
#  array([3.01832364, 4.03100332]),
#  array([3.01834696, 4.03103252]),
#  array([3.01836981, 4.03106113]),
#  array([3.01839219, 4.03108916]),
#  array([3.01841413, 4.03111663]),
#  array([3.01843563, 4.03114353]),
#  array([3.0184567, 4.0311699]),
#  array([3.01847735, 4.03119572]),
#  array([3.01849758, 4.03122103]),
#  array([3.0185174 , 4.03124582]),
#  array([3.01853683, 4.03127011]),
#  array([3.01855587, 4.03129391]),
#  array([3.01857453, 4.03131723]),
#  array([3.01859281, 4.03134007]),
#  array([3.01861073, 4.03136246]),
#  array([3.01862828, 4.03138438]),
#  array([3.01864549, 4.03140587]),
#  array([3.01866234, 4.03142692]),
#  array([3.01867887, 4.03144754]),
#  array([3.01869505, 4.03146775]),
#  array([3.01871092, 4.03148755]),
#  array([3.01872647, 4.03150695]),
#  array([3.0187417 , 4.03152595]),
#  array([3.01875663, 4.03154457]),
#  array([3.01877126, 4.03156281]),
#  array([3.0187856 , 4.03158068]),
#  array([3.01879964, 4.03159819]),
#  array([3.01881341, 4.03161535]),
#  array([3.0188269 , 4.03163216]),
#  array([3.01884012, 4.03164863]),
#  array([3.01885308, 4.03166476]),
#  array([3.01886577, 4.03168057]),
#  array([3.01887821, 4.03169606]),
#  array([3.0188904 , 4.03171123]),
#  array([3.01890235, 4.0317261 ]),
#  array([3.01891406, 4.03174067]),
#  array([3.01892553, 4.03175494]),
#  array([3.01893677, 4.03176892]),
#  array([3.01894779, 4.03178262]),
#  array([3.01895858, 4.03179605]),
#  array([3.01896916, 4.0318092 ]),
#  array([3.01897953, 4.03182208]),
#  array([3.01898969, 4.0318347 ]),
#  array([3.01899964, 4.03184707]),
#  array([3.0190094 , 4.03185919]),
#  array([3.01901896, 4.03187106]),
#  array([3.01902832, 4.03188269]),
#  array([3.0190375 , 4.03189409]),
#  array([3.0190465 , 4.03190525]),
#  array([3.01905532, 4.03191619]),
#  array([3.01906395, 4.03192691]),
#  array([3.01907242, 4.03193741]),
#  array([3.01908071, 4.0319477 ]),
#  array([3.01908884, 4.03195778]),
#  array([3.01909681, 4.03196766]),
#  array([3.01910462, 4.03197733]),
#  array([3.01911227, 4.03198681]),
#  array([3.01911976, 4.0319961 ]),
#  array([3.01912711, 4.0320052 ]),
#  array([3.01913431, 4.03201411]),
#  array([3.01914136, 4.03202285]),
#  array([3.01914827, 4.03203141]),
#  array([3.01915505, 4.03203979]),
#  array([3.01916169, 4.03204801]),
#  array([3.01916819, 4.03205606]),
#  array([3.01917457, 4.03206394]),
#  array([3.01918081, 4.03207167])]

# %% [markdown]
# ## 随机梯度下降法

# %%
def dJ_sgd(theta, X_b_i, y_i):
    return X_b_i.T.dot(X_b_i.dot(theta) - y_i) * 2.

# %%
history_theta = []
def sgd(X_b, y, initial_theta, n_iters):
    t0 = 5
    t1 = 50
    
    
    def learning_rate(t):
        return t0 / (t + t1)
    theta = initial_theta
    history_theta.append(theta)

    for cur_iter in range(n_iters):
        rand_i = np.random.randint(len(X_b))
        gradient = dJ_sgd(theta, X_b[rand_i], y[rand_i])
        theta = theta - learning_rate(cur_iter) * gradient
        history_theta.append(theta)

    return theta

# %%
# %%time
X_b = np.hstack([np.ones((len(X), 1)), X])
initial_theta = np.zeros(X_b.shape[1])

theta = sgd(X_b, y, initial_theta, n_iters=len(X_b)//3)
# Out:
# CPU times: user 31.2 ms, sys: 2.82 ms, total: 34 ms
# Wall time: 31.9 ms

# %%
theta
# Out:
# array([3.29998084, 4.29777543])

# %%
history_theta
# Out:
# [array([0., 0.]),
#  array([0.96827414, 1.60005162]),
#  array([0.9270109 , 1.65299764]),
#  array([-0.28146472,  2.49905125]),
#  array([0.62707135, 3.09871178]),
#  array([0.66876767, 3.11266777]),
#  array([1.13147443, 3.49282879]),
#  array([1.38883155, 3.50870866]),
#  array([1.79245007, 3.63783792]),
#  array([1.85609813, 3.7484571 ]),
#  array([2.05671594, 3.57899029]),
#  array([2.50895324, 3.85898013]),
#  array([2.43375915, 3.97011817]),
#  array([2.0127884 , 3.70761463]),
#  array([2.23005389, 3.81078822]),
#  array([2.31923407, 3.7517095 ]),
#  array([2.55989247, 3.93966446]),
#  array([1.93867994, 4.40494386]),
#  array([2.06353436, 4.51949289]),
#  array([1.94905488, 4.52383458]),
#  array([1.27455967, 4.90573998]),
#  array([1.31608089, 4.94968933]),
#  array([1.77044713, 4.9676253 ]),
#  array([1.76042383, 4.96132808]),
#  array([1.57209492, 4.9128491 ]),
#  array([1.86847096, 5.23984178]),
#  array([1.43396116, 5.19451696]),
#  array([1.90093687, 4.50174432]),
#  array([2.13655373, 4.4469954 ]),
#  array([3.25140424, 4.06183867]),
#  array([2.82833038, 4.42800451]),
#  array([2.43722681, 4.33632426]),
#  array([2.53047535, 4.23074162]),
#  array([2.98566314, 4.23787553]),
#  array([2.21789555, 5.11188016]),
#  array([2.42102659, 4.85295229]),
#  array([3.20234724, 2.26732104]),
#  array([3.28533379, 2.25306741]),
#  array([3.31304436, 2.28281199]),
#  array([2.89082854, 1.56220788]),
#  array([3.3465921 , 1.32063342]),
#  array([3.14866582, 1.38015323]),
#  array([1.76778809, 4.51913433]),
#  array([2.10948365, 4.53395148]),
#  array([1.87233381, 4.15842783]),
#  array([1.84854087, 4.11792395]),
#  array([2.03393226, 4.17529163]),
#  array([2.45652655, 4.435045  ]),
#  array([2.50139778, 4.46908711]),
#  array([2.38306446, 4.66170983]),
#  array([2.25335016, 4.83087824]),
#  array([2.24975051, 4.83138885]),
#  array([1.71646382, 3.88923097]),
#  array([1.53005409, 4.01087532]),
#  array([1.41016794, 3.8528781 ]),
#  array([1.69461258, 4.17262222]),
#  array([1.77481139, 4.10836949]),
#  array([1.87197826, 4.02056271]),
#  array([1.82753329, 3.95723557]),
#  array([1.5607839 , 4.59315819]),
#  array([1.11148891, 4.9602697 ]),
#  array([0.81403201, 4.42447132]),
#  array([1.28887751, 4.05160942]),
#  array([1.49662083, 4.30493996]),
#  array([1.55608995, 4.26014312]),
#  array([1.70812838, 4.3654091 ]),
#  array([1.61282625, 4.21927704]),
#  array([1.9431611 , 4.33947217]),
#  array([2.00925087, 4.31100333]),
#  array([2.37654776, 3.91365083]),
#  array([1.97907324, 3.67026596]),
#  array([2.04230405, 3.62408957]),
#  array([1.84991744, 3.3334063 ]),
#  array([1.95368868, 3.28183586]),
#  array([1.84569901, 3.30239883]),
#  array([2.23215235, 3.66158588]),
#  array([2.7121876, 4.1406898]),
#  array([2.57476355, 3.97084138]),
#  array([1.95672184, 3.78621074]),
#  array([1.96644507, 3.77483804]),
#  array([2.50451318, 3.753026  ]),
#  array([2.59316896, 3.70929432]),
#  array([2.31922927, 3.91852648]),
#  array([2.49795196, 4.17100347]),
#  array([2.42959154, 4.1329573 ]),
#  array([2.08270753, 4.48796726]),
#  array([2.03815326, 4.55013116]),
#  array([2.14475002, 4.55527987]),
#  array([2.2532379 , 4.51810133]),
#  array([2.28456289, 4.48351346]),
#  array([2.17548539, 4.41596353]),
#  array([2.32485462, 4.38994368]),
#  array([2.14374986, 4.06606653]),
#  array([2.20379087, 4.11748807]),
#  array([2.3625543 , 3.93032002]),
#  array([2.35205014, 3.92511178]),
#  array([1.91532345, 4.0466466 ]),
#  array([1.81647572, 4.20715755]),
#  array([1.82450754, 4.19167772]),
#  array([2.02562943, 4.15951829]),
#  array([2.18965908, 4.23418408]),
#  array([2.34687872, 3.89840757]),
#  array([2.08476548, 3.75937027]),
#  array([2.5098649 , 4.07741736]),
#  array([2.58481918, 3.97277218]),
#  array([2.80104515, 3.98013658]),
#  array([2.57719159, 3.95849424]),
#  array([2.33758092, 4.00865648]),
#  array([1.96535073, 4.12772125]),
#  array([1.93906386, 4.15833785]),
#  array([2.04818598, 4.00677039]),
#  array([2.31753156, 4.37891982]),
#  array([2.3852396 , 4.27166991]),
#  array([2.57851158, 4.14679698]),
#  array([2.56562949, 4.13316156]),
#  array([2.59516002, 4.01542099]),
#  array([2.6660799 , 4.03463503]),
#  array([2.49423866, 3.84954829]),
#  array([2.42599609, 3.93244137]),
#  array([2.4191385 , 3.93085293]),
#  array([2.54176197, 3.95365949]),
#  array([2.83501571, 3.69947678]),
#  array([2.70240774, 3.57107823]),
#  array([2.97917764, 3.51395276]),
#  array([2.98860407, 3.504687  ]),
#  array([3.10115257, 3.53091051]),
#  array([3.07664148, 3.5055588 ]),
#  array([2.96498268, 3.57245766]),
#  array([3.09529523, 3.69047233]),
#  array([3.30614357, 3.59111502]),
#  array([3.48234203, 3.56356035]),
#  array([3.76831457, 4.05959927]),
#  array([3.71094803, 4.00378902]),
#  array([3.72034536, 3.99417115]),
#  array([3.50116899, 4.08391126]),
#  array([3.21446702, 4.23245364]),
#  array([2.96393644, 4.48642298]),
#  array([3.02557025, 4.55828387]),
#  array([2.89867389, 4.49985879]),
#  array([2.88960097, 4.50738668]),
#  array([2.91319434, 4.4948066 ]),
#  array([3.12746317, 4.5138436 ]),
#  array([3.33587645, 4.54348365]),
#  array([3.444691  , 4.63342246]),
#  array([3.43420566, 4.63088476]),
#  array([3.41760848, 4.62378233]),
#  array([3.52045353, 4.5654499 ]),
#  array([3.38351907, 4.50114811]),
#  array([3.37561247, 4.49508601]),
#  array([3.15471541, 4.35683295]),
#  array([3.34169902, 4.42781586]),
#  array([3.37724183, 4.47993927]),
#  array([3.31528931, 4.44852768]),
#  array([3.27706389, 4.4074528 ]),
#  array([3.3424185 , 4.39843921]),
#  array([3.49538245, 4.36170578]),
#  array([3.72898206, 4.25887299]),
#  array([3.6982079 , 4.19990744]),
#  array([3.76700782, 4.25268889]),
#  array([3.8977345 , 4.31946017]),
#  array([3.79608875, 4.43784801]),
#  array([3.79175351, 4.43597385]),
#  array([3.57932935, 4.37156476]),
#  array([3.60625723, 4.38190707]),
#  array([3.46229168, 4.09156674]),
#  array([3.49815066, 4.04691847]),
#  array([3.43683495, 3.99050983]),
#  array([3.43431056, 3.99138082]),
#  array([3.40098347, 3.99570885]),
#  array([3.64122067, 4.11147022]),
#  array([3.81053317, 4.39644461]),
#  array([4.10384421, 4.22171434]),
#  array([3.78665186, 4.35529944]),
#  array([3.84605668, 4.29610886]),
#  array([3.7377227 , 4.31231946]),
#  array([3.50880235, 4.46587984]),
#  array([3.47107601, 4.50610466]),
#  array([3.49547996, 4.4677054 ]),
#  array([3.61837125, 4.47400742]),
#  array([3.46596189, 4.67888671]),
#  array([3.28511666, 4.68393659]),
#  array([3.28800858, 4.68128498]),
#  array([3.32742545, 4.63872385]),
#  array([3.17873256, 4.9105571 ]),
#  array([3.12939503, 4.89400705]),
#  array([3.02498047, 4.71651126]),
#  array([3.20901283, 4.67242689]),
#  array([3.17970962, 4.66612733]),
#  array([3.0366722 , 4.73309087]),
#  array([3.1814197 , 4.59807894]),
#  array([3.21556554, 4.62362678]),
#  array([3.17540723, 4.59648923]),
#  array([3.26636916, 4.61145282]),
#  array([3.39099733, 4.35029401]),
#  array([3.32112255, 4.41484041]),
#  array([3.37755779, 4.37977467]),
#  array([3.34044666, 4.39547082]),
#  array([3.34321531, 4.39236451]),
#  array([3.26742781, 4.29083281]),
#  array([3.30537846, 4.3205016 ]),
#  array([3.19113633, 4.37361274]),
#  array([3.19425684, 4.37781271]),
#  array([3.12069066, 4.29841277]),
#  array([3.06587535, 4.27526726]),
#  array([2.98841945, 4.2116198 ]),
#  array([3.01195628, 4.17564409]),
#  array([2.9847054 , 4.12968532]),
#  array([3.14593535, 4.28873568]),
#  array([3.1681434 , 4.29702844]),
#  array([3.16770035, 4.29709993]),
#  array([3.20927892, 4.27954213]),
#  array([3.36470858, 4.12847141]),
#  array([3.50937788, 3.75855195]),
#  array([3.18249255, 3.96386478]),
#  array([3.23283349, 3.94736457]),
#  array([3.2553439 , 3.95681856]),
#  array([2.86348632, 4.03757104]),
#  array([2.84031769, 4.0794881 ]),
#  array([2.79953176, 4.03137269]),
#  array([2.64368079, 4.0583855 ]),
#  array([2.8766523 , 3.73587845]),
#  array([2.80564443, 3.69401347]),
#  array([2.83013638, 3.68860489]),
#  array([2.77902491, 3.65612886]),
#  array([2.76305952, 3.67196302]),
#  array([2.60630656, 3.70527922]),
#  array([2.65430754, 3.66136575]),
#  array([2.45103977, 3.64804067]),
#  array([2.71399424, 3.73799703]),
#  array([2.47614152, 3.46761957]),
#  array([2.31639086, 3.4223903 ]),
#  array([2.39551366, 3.438679  ]),
#  array([2.43767291, 3.43914489]),
#  array([2.52266004, 3.48066052]),
#  array([2.36154093, 3.95045473]),
#  array([2.4472553 , 3.79858527]),
#  array([2.46457244, 3.79950784]),
#  array([2.51313642, 3.84391045]),
#  array([2.59876769, 3.77722595]),
#  array([2.60763189, 3.79477582]),
#  array([2.4891671 , 3.81382151]),
#  array([2.53991639, 3.80596105]),
#  array([2.67249399, 4.02174038]),
#  array([2.75680492, 4.06047425]),
#  array([2.76390159, 4.06049526]),
#  array([2.8006969 , 4.09081446]),
#  array([2.75190335, 4.13010256]),
#  array([3.02657101, 3.84582663]),
#  array([2.9444014 , 3.95893319]),
#  array([2.9036383 , 3.98054776]),
#  array([2.84036842, 4.01101458]),
#  array([2.74718528, 3.9683104 ]),
#  array([2.64116966, 4.10168572]),
#  array([2.69960482, 4.11918829]),
#  array([2.72958732, 4.09155118]),
#  array([2.78187609, 4.19442091]),
#  array([2.71585589, 4.19171197]),
#  array([2.7344266 , 4.20940509]),
#  array([2.5938564 , 3.98019109]),
#  array([2.70463838, 3.9929315 ]),
#  array([2.73554606, 4.00397365]),
#  array([2.66706846, 3.9742761 ]),
#  array([2.67216641, 3.97442407]),
#  array([2.63416832, 3.97582339]),
#  array([2.64345814, 3.978773  ]),
#  array([2.56245438, 3.97708514]),
#  array([2.54932158, 3.99595567]),
#  array([2.61227622, 4.04804726]),
#  array([2.58668184, 4.05363252]),
#  array([2.72542418, 3.98958655]),
#  array([2.67370226, 3.99978727]),
#  array([2.66589769, 3.988513  ]),
#  array([2.63326832, 3.95934778]),
#  array([2.63989643, 3.96024387]),
#  array([2.59842907, 4.03353153]),
#  array([2.67919823, 4.00472475]),
#  array([2.71769578, 3.99163844]),
#  array([2.81436687, 4.00295778]),
#  array([2.88840789, 3.97223016]),
#  array([2.89078504, 3.97154356]),
#  array([2.83106169, 4.11203765]),
#  array([2.80563482, 4.04075114]),
#  array([2.69554291, 3.94348115]),
#  array([2.70954133, 3.94187781]),
#  array([2.77086649, 3.95173453]),
#  array([2.58404191, 4.11495899]),
#  array([2.64358787, 4.18574557]),
#  array([2.50474661, 4.24336064]),
#  array([2.4905871 , 4.24192809]),
#  array([2.49505601, 4.2488832 ]),
#  array([2.51375898, 4.22693746]),
#  array([2.49229219, 4.27304077]),
#  array([2.42547257, 4.28161299]),
#  array([2.68107135, 4.20872752]),
#  array([2.70771408, 4.25668973]),
#  array([2.81082787, 4.28359532]),
#  array([2.84746513, 4.34584883]),
#  array([2.84884009, 4.34441636]),
#  array([2.93159024, 4.42685969]),
#  array([3.01191119, 4.29992161]),
#  array([3.01967225, 4.27275331]),
#  array([3.00478762, 4.23329352]),
#  array([2.99892957, 4.24003863]),
#  array([2.97188138, 4.2570572 ]),
#  array([2.97459304, 4.25374664]),
#  array([2.94013996, 4.27181337]),
#  array([2.90316544, 4.28230701]),
#  array([3.00889537, 4.30924188]),
#  array([2.90037141, 4.28636365]),
#  array([2.86600941, 4.26199485]),
#  array([2.77443347, 4.34610516]),
#  array([2.80393869, 4.31424633]),
#  array([2.7897126 , 4.32340608]),
#  array([2.87882624, 4.32034239]),
#  array([2.9868843 , 4.27986592]),
#  array([2.97785999, 4.28563107]),
#  array([2.87037472, 4.48931683]),
#  array([2.75660557, 4.32834283]),
#  array([2.76930303, 4.31973659]),
#  array([2.94757373, 4.40651078]),
#  array([3.01472016, 4.3560547 ]),
#  array([2.89439262, 4.41123704]),
#  array([2.84609774, 4.38003048]),
#  array([2.7988951 , 4.38751029]),
#  array([2.85162086, 4.45621194]),
#  array([2.81361028, 4.43505705]),
#  array([2.81746455, 4.43600524]),
#  array([2.7560949, 4.5769931]),
#  array([2.70789499, 4.65763396]),
#  array([2.60661926, 4.49781629]),
#  array([2.52861388, 4.52796128]),
#  array([2.44729074, 4.49171385]),
#  array([2.35547594, 4.52095201]),
#  array([2.47423878, 4.81095262]),
#  array([2.53516706, 4.84820496]),
#  array([2.63417142, 4.9439113 ]),
#  array([2.5940896 , 4.90897381]),
#  array([2.64024216, 4.88018905]),
#  array([2.75663144, 4.89254414]),
#  array([2.74431685, 4.8926777 ]),
#  array([2.75498193, 4.88163962]),
#  array([2.79795904, 4.92363337]),
#  array([2.71563014, 5.00035031]),
#  array([2.65392496, 4.95505153]),
#  array([2.6320733, 4.9661746]),
#  array([2.54952645, 4.9164704 ]),
#  array([2.68982562, 4.70074134]),
#  array([2.78438922, 4.5989163 ]),
#  array([2.80436563, 4.6446529 ]),
#  array([2.85735986, 4.60332372]),
#  array([2.93748201, 4.54272906]),
#  array([3.12774195, 4.89077475]),
#  array([3.17899605, 4.97315296]),
#  array([3.23775324, 4.88176399]),
#  array([3.24614903, 4.8803122 ]),
#  array([3.18564144, 4.82992719]),
#  array([3.12056209, 4.78661996]),
#  array([3.18904541, 4.75220421]),
#  array([3.1844521 , 4.75533959]),
#  array([3.21448095, 4.70360223]),
#  array([3.14154272, 4.57830182]),
#  array([3.19059824, 4.59750409]),
#  array([3.18823028, 4.59423403]),
#  array([3.24093173, 4.6289251 ]),
#  array([3.248291  , 4.64047101]),
#  array([3.16857462, 4.60760825]),
#  array([3.14506082, 4.58931754]),
#  array([3.14894678, 4.58798252]),
#  array([3.13342227, 4.58483334]),
#  array([3.11688142, 4.58886473]),
#  array([3.08347987, 4.5668429 ]),
#  array([3.00816785, 4.51455319]),
#  array([3.04819031, 4.47999824]),
#  array([3.10624817, 4.49356611]),
#  array([3.10722503, 4.49456045]),
#  array([3.06386822, 4.4780902 ]),
#  array([3.04333651, 4.49802546]),
#  array([3.01539499, 4.52051167]),
#  array([2.94148153, 4.56943933]),
#  array([2.96945138, 4.54182147]),
#  array([2.9327057 , 4.47001946]),
#  array([2.73620729, 4.18768887]),
#  array([2.72614292, 4.18930711]),
#  array([2.77648225, 4.10346482]),
#  array([2.8685318 , 4.08950431]),
#  array([2.94438171, 4.24063388]),
#  array([2.87004524, 4.18161889]),
#  array([2.80722911, 4.16902152]),
#  array([2.95554009, 3.98580601]),
#  array([2.94339387, 3.96132009]),
#  array([2.88276556, 3.99707984]),
#  array([2.85292905, 3.96006215]),
#  array([2.7700076 , 4.02339665]),
#  array([2.68359107, 4.01584255]),
#  array([2.72563245, 4.07405912]),
#  array([2.8782589 , 4.14980207]),
#  array([2.91094758, 4.17425966]),
#  array([2.94280979, 4.17792868]),
#  array([3.05429096, 4.20832753]),
#  array([3.03341818, 4.23563381]),
#  array([2.99566877, 4.20419966]),
#  array([3.12106487, 4.1816379 ]),
#  array([3.15869756, 4.19192597]),
#  array([3.24834203, 4.05954249]),
#  array([3.25349946, 4.05897125]),
#  array([3.23234974, 4.09641177]),
#  array([3.25450507, 4.08434349]),
#  array([3.20722396, 4.11080444]),
#  array([3.21904746, 4.13293551]),
#  array([3.26871505, 4.17056622]),
#  array([3.38590302, 4.1793002 ]),
#  array([3.26705947, 3.98957017]),
#  array([3.33413372, 4.01462962]),
#  array([3.43253416, 4.11283915]),
#  array([3.34121036, 4.18877264]),
#  array([3.26622878, 4.09850084]),
#  array([3.2929465 , 4.13548891]),
#  array([3.29783279, 4.13247605]),
#  array([3.30372477, 4.12153819]),
#  array([3.38828504, 4.11649402]),
#  array([3.30747515, 4.03732951]),
#  array([3.35586873, 3.99375038]),
#  array([3.3719453 , 3.99660087]),
#  array([3.32048337, 4.00050229]),
#  array([3.27526157, 3.9923986 ]),
#  array([3.23516211, 4.0199473 ]),
#  array([3.20703242, 4.03954022]),
#  array([3.21503126, 4.03596248]),
#  array([3.19736072, 4.0464671 ]),
#  array([3.19211118, 4.04269912]),
#  array([3.21440657, 4.04340198]),
#  array([3.14519092, 3.9622866 ]),
#  array([3.17796103, 4.00049435]),
#  array([3.16614348, 3.99704974]),
#  array([3.18477854, 3.99898792]),
#  array([3.26164492, 3.84172024]),
#  array([3.31763662, 3.92920143]),
#  array([3.29647264, 3.96549795]),
#  array([3.32492472, 3.91161336]),
#  array([3.43388019, 3.91622955]),
#  array([3.427477  , 3.92022455]),
#  array([3.36302177, 3.94890826]),
#  array([3.34527957, 3.93850547]),
#  array([3.35865447, 3.95697565]),
#  array([3.31172548, 3.97575926]),
#  array([3.27483533, 3.97962157]),
#  array([3.26923334, 3.98492044]),
#  array([3.29350607, 3.96469331]),
#  array([3.24080441, 3.99380561]),
#  array([3.17930071, 4.00169585]),
#  array([3.21145056, 4.05415307]),
#  array([3.23302013, 4.07549976]),
#  array([3.2222487 , 4.07355528]),
#  array([3.16411422, 3.88679993]),
#  array([3.22364191, 3.86190532]),
#  array([3.24367406, 3.88564764]),
#  array([3.2041792 , 3.83233056]),
#  array([3.10251105, 3.9317941 ]),
#  array([3.10987231, 3.93036369]),
#  array([3.06824584, 3.91426439]),
#  array([3.04798047, 3.93597167]),
#  array([3.08288237, 3.9138969 ]),
#  array([3.12307957, 3.93344635]),
#  array([3.06617747, 3.92527046]),
#  array([3.06978726, 3.92590902]),
#  array([3.08756114, 3.91959142]),
#  array([3.1775888, 3.9360797]),
#  array([3.14958433, 3.92428698]),
#  array([3.1150285 , 3.95950017]),
#  array([3.08342869, 3.97739041]),
#  array([3.0009434 , 4.02700034]),
#  array([2.91022546, 4.22632784]),
#  array([3.00303521, 4.09467986]),
#  array([3.0420884 , 4.02570299]),
#  array([3.04151287, 4.02690793]),
#  array([3.11327316, 3.90372957]),
#  array([3.05361686, 3.91035561]),
#  array([3.01874944, 3.90116718]),
#  array([3.1175271 , 3.97201771]),
#  array([3.08772395, 3.9589098 ]),
#  array([3.06336912, 3.95785738]),
#  array([3.17117145, 4.11078618]),
#  array([3.17818004, 4.11014572]),
#  array([3.15370732, 4.08111473]),
#  array([3.10578397, 4.02915395]),
#  array([3.07644572, 4.05499477]),
#  array([3.0399587 , 4.06426529]),
#  array([3.00452531, 4.0894901 ]),
#  array([3.01033187, 4.08799872]),
#  array([2.9777142 , 4.08537867]),
#  array([3.08842975, 4.03665707]),
#  array([3.09208739, 4.03390258]),
#  array([3.08293304, 4.02869926]),
#  array([3.14841501, 4.00319384]),
#  array([3.17821976, 4.02114609]),
#  array([3.14441132, 4.00888503]),
#  array([3.12570003, 4.02837344]),
#  array([3.16395068, 4.02745272]),
#  array([3.10528509, 4.02557869]),
#  array([3.03693535, 3.92216121]),
#  array([3.0385297 , 3.92116648]),
#  array([3.0243426, 3.9169469]),
#  array([3.02204199, 3.91833705]),
#  array([3.05027823, 3.9048465 ]),
#  array([3.05116791, 3.90470812]),
#  array([3.07360541, 3.88947328]),
#  array([2.97528922, 3.88108617]),
#  array([3.01722208, 3.8096092 ]),
#  array([2.88104496, 3.61394877]),
#  array([2.96114777, 3.73909586]),
#  array([2.98023862, 3.73383884]),
#  array([2.96637943, 3.73968429]),
#  array([2.95793567, 3.73902616]),
#  array([2.97036854, 3.74415693]),
#  array([2.99227356, 3.70550957]),
#  array([2.94253865, 3.65768294]),
#  array([2.97926799, 3.68290669]),
#  array([3.03048063, 3.68613023]),
#  array([2.98276103, 3.6643903 ]),
#  array([2.99684146, 3.64020305]),
#  array([2.88548786, 3.84395638]),
#  array([2.85193799, 3.89255234]),
#  array([2.86247818, 3.90457354]),
#  array([2.93851927, 3.75070672]),
#  array([3.03657127, 3.73306481]),
#  array([3.01584395, 3.71453804]),
#  array([3.03877883, 3.71902126]),
#  array([3.02605286, 3.69190197]),
#  array([2.9854504 , 3.73769837]),
#  array([3.08905313, 3.78550011]),
#  array([2.99892758, 3.7727961 ]),
#  array([2.94369777, 3.79676147]),
#  array([2.94762173, 3.79152907]),
#  array([2.98106371, 3.78011   ]),
#  array([2.95189315, 3.71990286]),
#  array([2.97669784, 3.72942971]),
#  array([2.99445081, 3.71410199]),
#  array([2.89573194, 3.85549469]),
#  array([2.89431895, 3.8572868 ]),
#  array([3.02552664, 3.92286221]),
#  array([2.97216009, 3.83977943]),
#  array([3.02118156, 3.87364889]),
#  array([2.97263186, 3.8839988 ]),
#  array([2.91368854, 3.90317813]),
#  array([3.01042674, 4.05436913]),
#  array([3.04662605, 4.02716775]),
#  array([3.01545996, 4.03361863]),
#  array([2.9735605, 4.0397335]),
#  array([2.94799898, 4.06950526]),
#  array([2.90321826, 4.00758357]),
#  array([2.94911681, 4.00568274]),
#  array([2.95998883, 4.00897618]),
#  array([2.87547998, 3.9840224 ]),
#  array([2.85096755, 3.98879956]),
#  array([2.89138882, 3.99798582]),
#  array([2.84017647, 3.94250051]),
#  array([2.77387448, 3.84008842]),
#  array([2.79342886, 3.82924273]),
#  array([2.90866787, 3.87449096]),
#  array([2.97238479, 3.86133683]),
#  array([2.98542863, 3.85537769]),
#  array([3.10844594, 4.02188999]),
#  array([3.07553778, 4.05663709]),
#  array([3.11067478, 4.1161384 ]),
#  array([3.11653215, 4.11534886]),
#  array([3.04255112, 4.17463979]),
#  array([3.0323639, 4.1851833]),
#  array([3.02746939, 4.17220775]),
#  array([3.04520686, 4.18207471]),
#  array([3.06930376, 4.1596299 ]),
#  array([3.06978714, 4.15964378]),
#  array([3.14569354, 4.29362489]),
#  array([3.14477213, 4.29465097]),
#  array([3.10411601, 4.23236188]),
#  array([3.0712569 , 4.25668331]),
#  array([3.08096792, 4.25126699]),
#  array([3.05290887, 4.22028031]),
#  array([3.13186306, 4.276912  ]),
#  array([3.08200341, 4.29653169]),
#  array([3.09209956, 4.28109987]),
#  array([3.06092535, 4.25992686]),
#  array([3.09526714, 4.23331392]),
#  array([3.16699503, 4.03829555]),
#  array([3.22441796, 3.9816234 ]),
#  array([3.19321317, 3.9768609 ]),
#  array([3.18192981, 3.96363286]),
#  array([3.16377628, 3.95062686]),
#  array([3.26097228, 3.92783948]),
#  array([3.19801903, 3.87711006]),
#  array([3.2478149 , 3.86448632]),
#  array([3.24492929, 3.86142123]),
#  array([3.24413652, 3.86130428]),
#  array([3.22678386, 3.88140845]),
#  array([3.23856082, 3.87805853]),
#  array([3.19262367, 4.00323039]),
#  array([3.20937057, 3.99463999]),
#  array([3.18515822, 3.95852078]),
#  array([3.2710056 , 3.97873351]),
#  array([3.33766687, 4.06421811]),
#  array([3.26482167, 4.09479554]),
#  array([3.27555592, 4.08870809]),
#  array([3.30103582, 4.10542943]),
#  array([3.28998708, 4.11162071]),
#  array([3.32756712, 4.06523034]),
#  array([3.34543105, 4.0684457 ]),
#  array([3.3184811 , 4.08228574]),
#  array([3.25528043, 4.13483553]),
#  array([3.25037382, 4.13355434]),
#  array([3.29872024, 4.11156197]),
#  array([3.25768151, 4.19724695]),
#  array([3.2764661 , 4.21834505]),
#  array([3.30383517, 4.27235236]),
#  array([3.25688424, 4.24259272]),
#  array([3.35834998, 3.9673261 ]),
#  array([3.3743703 , 3.97266065]),
#  array([3.38044078, 3.98201295]),
#  array([3.30533096, 3.98287138]),
#  array([3.27541363, 3.97673211]),
#  array([3.28480804, 3.97588294]),
#  array([3.28375945, 3.97426137]),
#  array([3.249423  , 3.92551023]),
#  array([3.23310618, 3.93804597]),
#  array([3.25373105, 3.94144426]),
#  array([3.29723827, 4.01225531]),
#  array([3.33954565, 3.93788592]),
#  array([3.26337194, 3.83588051]),
#  array([3.29328426, 3.84144868]),
#  array([3.30539489, 3.8309925 ]),
#  array([3.27446209, 3.82385344]),
#  array([3.31567012, 3.8421036 ]),
#  array([3.30358388, 3.81391056]),
#  array([3.38834227, 3.97169046]),
#  array([3.3456959 , 3.96347567]),
#  array([3.35937966, 3.9595487 ]),
#  array([3.40512362, 3.96901496]),
#  array([3.40319741, 3.96867668]),
#  array([3.32347844, 4.03010475]),
#  array([3.27680661, 4.04941653]),
#  array([3.26482358, 4.04285263]),
#  array([3.23683402, 4.03433599]),
#  array([3.20115947, 4.02443959]),
#  array([3.17333601, 4.0418099 ]),
#  array([3.11331014, 4.11390675]),
#  array([3.10874513, 4.11482586]),
#  array([3.19965236, 3.98195417]),
#  array([3.24270802, 4.03033867]),
#  array([3.2369479 , 4.02745508]),
#  array([3.29747599, 4.05451027]),
#  array([3.31275108, 4.05317757]),
#  array([3.27214171, 4.05132899]),
#  array([3.26992321, 4.05168695]),
#  array([3.23220212, 4.00823492]),
#  array([3.24207179, 4.02039151]),
#  array([3.24745004, 4.02052398]),
#  array([3.3303098 , 3.90199812]),
#  array([3.33129879, 3.90119359]),
#  array([3.3220306, 3.8848486]),
#  array([3.34026597, 3.86947378]),
#  array([3.33843878, 3.86940738]),
#  array([3.319526  , 3.86843462]),
#  array([3.31816999, 3.86829138]),
#  array([3.27674724, 3.85813288]),
#  array([3.28272025, 3.85836176]),
#  array([3.23151549, 3.84849759]),
#  array([3.28860851, 3.92624602]),
#  array([3.25170713, 3.95757968]),
#  array([3.35785624, 4.15926557]),
#  array([3.39021439, 4.12406186]),
#  array([3.43307189, 4.15362389]),
#  array([3.48282556, 4.13517661]),
#  array([3.47416784, 4.13499812]),
#  array([3.49952825, 4.16592572]),
#  array([3.52521879, 4.1807942 ]),
#  array([3.53958457, 4.20841891]),
#  array([3.49038675, 4.2348254 ]),
#  array([3.46882339, 4.20162104]),
#  array([3.48340892, 4.20806111]),
#  array([3.41606756, 4.17249903]),
#  array([3.41928217, 4.1750123 ]),
#  array([3.44192293, 4.19555284]),
#  array([3.42784447, 4.20485698]),
#  array([3.46404385, 4.19406064]),
#  array([3.40362465, 4.19375422]),
#  array([3.37789607, 4.20333255]),
#  array([3.38246701, 4.19939166]),
#  array([3.33942861, 4.14572225]),
#  array([3.31514595, 4.13247724]),
#  array([3.33368094, 4.13540109]),
#  array([3.35805148, 4.115339  ]),
#  array([3.31055674, 4.1365076 ]),
#  array([3.30841232, 4.13804249]),
#  array([3.37097931, 4.09990696]),
#  array([3.33866901, 4.09035055]),
#  array([3.31817461, 4.09163064]),
#  array([3.32045654, 4.0929388 ]),
#  array([3.30822744, 4.09215996]),
#  array([3.34265606, 4.08180071]),
#  array([3.35234724, 4.0831398 ]),
#  array([3.30531287, 4.09817805]),
#  array([3.23588613, 4.17652014]),
#  array([3.22299638, 4.16585878]),
#  array([3.23182556, 4.17010989]),
#  array([3.22036019, 4.18453523]),
#  array([3.19274707, 4.18061818]),
#  array([3.15254173, 4.22434466]),
#  array([3.14130577, 4.21152311]),
#  array([3.12144003, 4.18152175]),
#  array([3.13253812, 4.16492038]),
#  array([3.14054251, 4.17429341]),
#  array([3.15867458, 4.2144785 ]),
#  array([3.21670111, 4.15653344]),
#  array([3.15379215, 4.01045015]),
#  array([3.18133423, 4.02595346]),
#  array([3.24699755, 4.13202698]),
#  array([3.28905354, 4.11857553]),
#  array([3.29609445, 4.11460519]),
#  array([3.26677882, 4.1464875 ]),
#  array([3.38425312, 4.15286183]),
#  array([3.28708695, 4.18112567]),
#  array([3.30535416, 4.13756059]),
#  array([3.32462404, 4.12628839]),
#  array([3.3159617 , 4.11822617]),
#  array([3.35353705, 4.1576095 ]),
#  array([3.40663066, 4.17895766]),
#  array([3.40387276, 4.17825144]),
#  array([3.39917173, 4.18765383]),
#  array([3.34523471, 4.16725791]),
#  array([3.36809949, 4.17708117]),
#  array([3.40732316, 4.1555694 ]),
#  array([3.42091203, 4.14634269]),
#  array([3.36916166, 4.17201146]),
#  array([3.43215066, 4.13228698]),
#  array([3.45036661, 4.13705315]),
#  array([3.41222865, 4.1244466 ]),
#  array([3.40109741, 4.12462736]),
#  array([3.36157586, 4.13191686]),
#  array([3.36750344, 4.12769573]),
#  array([3.38101714, 4.1388776 ]),
#  array([3.34908406, 4.16458425]),
#  array([3.33154899, 4.14008309]),
#  array([3.35188532, 4.14899164]),
#  array([3.33814532, 4.16373266]),
#  array([3.31225593, 4.12801905]),
#  array([3.36587022, 4.08783697]),
#  array([3.42098435, 4.0906507 ]),
#  array([3.45119861, 4.10006799]),
#  array([3.40217087, 4.11602093]),
#  array([3.4599501 , 4.16410702]),
#  array([3.46095081, 4.16553426]),
#  array([3.44306172, 4.17829178]),
#  array([3.33473792, 4.27292454]),
#  array([3.33183854, 4.27226531]),
#  array([3.26321885, 4.27538993]),
#  array([3.29948931, 4.33368567]),
#  array([3.26940125, 4.35764244]),
#  array([3.29298527, 4.33343623]),
#  array([3.31102079, 4.33480359]),
#  array([3.32380078, 4.34915757]),
#  array([3.31730075, 4.35077513]),
#  array([3.33365538, 4.35135248]),
#  array([3.3781726 , 4.35542031]),
#  array([3.36094422, 4.37261622]),
#  array([3.32715025, 4.40738357]),
#  array([3.30501692, 4.38548063]),
#  array([3.34159348, 4.31024044]),
#  array([3.25419798, 4.1788017 ]),
#  array([3.25779618, 4.17629601]),
#  array([3.29654384, 4.18751832]),
#  array([3.27423506, 4.22897896]),
#  array([3.27847156, 4.22456328]),
#  array([3.27478897, 4.22377921]),
#  array([3.24166636, 4.20647517]),
#  array([3.24648262, 4.20360309]),
#  array([3.20557651, 4.21140499]),
#  array([3.17651082, 4.23756991]),
#  array([3.18829413, 4.2368046 ]),
#  array([3.20766138, 4.21183746]),
#  array([3.25964249, 4.09610794]),
#  array([3.25102026, 4.10521126]),
#  array([3.27767608, 4.06061434]),
#  array([3.2437755 , 4.02863581]),
#  array([3.2015424 , 4.03637588]),
#  array([3.17747798, 4.04598892]),
#  array([3.18340604, 4.0451421 ]),
#  array([3.15500096, 4.05130879]),
#  array([3.16154271, 4.06063882]),
#  array([3.13649095, 4.05309134]),
#  array([3.13858803, 4.0507715 ]),
#  array([3.11747384, 4.02197618]),
#  array([3.04000795, 4.07654482]),
#  array([3.0237135 , 4.05895823]),
#  array([3.05135172, 4.09623185]),
#  array([2.98782887, 4.09325112]),
#  array([2.97267142, 4.09411156]),
#  array([3.01652112, 4.11263908]),
#  array([3.0191424 , 4.11064747]),
#  array([2.98699553, 4.15785158]),
#  array([2.90792492, 4.18949016]),
#  array([2.91588625, 4.18666262]),
#  array([2.91393388, 4.18809322]),
#  array([3.01560104, 4.24661028]),
#  array([3.01044934, 4.24681158]),
#  array([2.96342176, 4.21406235]),
#  array([2.91443141, 4.22515359]),
#  array([2.91390702, 4.22564411]),
#  array([2.8862168 , 4.27697653]),
#  array([2.88612469, 4.27687047]),
#  array([2.8465042 , 4.24094822]),
#  array([2.86940679, 4.21760404]),
#  array([2.83091564, 4.18776622]),
#  array([2.86543122, 4.15378081]),
#  array([2.87013042, 4.15215607]),
#  array([2.87940676, 4.14415837]),
#  array([2.90338564, 4.1305011 ]),
#  array([2.85886786, 4.13316216]),
#  array([2.88668478, 4.13583573]),
#  array([2.90960057, 4.1531211 ]),
#  array([2.94999984, 4.10487212]),
#  array([3.00162199, 4.07221116]),
#  array([2.96848132, 4.0799111 ]),
#  array([3.01201753, 4.09878577]),
#  array([2.99371122, 4.09014309]),
#  array([3.01173847, 4.07752704]),
#  array([3.0715374 , 3.96835818]),
#  array([3.09911647, 3.99858303]),
#  array([3.11165612, 3.97588315]),
#  array([3.1127123 , 3.97532227]),
#  array([3.12381905, 3.97056784]),
#  array([3.10619377, 3.95657756]),
#  array([3.11312981, 3.95656146]),
#  array([3.10095168, 3.9578909 ]),
#  array([3.09541044, 3.9633312 ]),
#  array([3.0281221 , 3.93134549]),
#  array([3.00969631, 3.96685777]),
#  array([2.97875964, 3.99755104]),
#  array([2.99057165, 3.9910387 ]),
#  array([2.96618838, 4.00682436]),
#  array([2.94740835, 4.04110768]),
#  array([2.96855747, 4.05137461]),
#  array([2.98057131, 4.03156373]),
#  array([3.01356686, 4.03819253]),
#  array([3.02206454, 4.02758905]),
#  array([3.00071524, 4.01442587]),
#  array([2.98392725, 4.01168547]),
#  array([2.97566529, 4.00222822]),
#  array([2.96306911, 4.01870686]),
#  array([2.98603201, 4.00223913]),
#  array([2.96916739, 4.0006278 ]),
#  array([2.92438723, 3.99671334]),
#  array([2.95165409, 4.00711814]),
#  array([2.96785382, 4.01677312]),
#  array([2.98832831, 4.02995725]),
#  array([2.99571357, 4.02240142]),
#  array([3.01701431, 4.01336927]),
#  array([3.04453026, 4.04505867]),
#  array([3.09191939, 4.05365944]),
#  array([3.08160787, 4.04571361]),
#  array([3.08760338, 4.05719987]),
#  array([3.08041202, 4.05535344]),
#  array([3.1231624 , 4.05925982]),
#  array([3.06553421, 4.12283609]),
#  array([3.08960823, 4.11924617]),
#  array([3.11004391, 4.11579604]),
#  array([3.15570368, 4.12126093]),
#  array([3.13106851, 4.13562304]),
#  array([3.17066691, 4.15884496]),
#  array([3.1706727 , 4.15884515]),
#  array([3.12304333, 4.15157956]),
#  array([3.14127295, 4.14866464]),
#  array([3.14772575, 4.15866271]),
#  array([3.15623056, 4.16940207]),
#  array([3.13758415, 4.19720529]),
#  array([3.04796166, 4.23837922]),
#  array([3.00375517, 4.26679826]),
#  array([2.97675227, 4.29457894]),
#  array([2.96135277, 4.26934086]),
#  array([2.9251789 , 4.28208293]),
#  array([2.88467459, 4.23200276]),
#  array([2.86314972, 4.25354763]),
#  array([2.90251986, 4.21051729]),
#  array([2.92234154, 4.21122084]),
#  array([2.91172544, 4.19188281]),
#  array([2.9264094 , 4.17104607]),
#  array([2.91325757, 4.18442906]),
#  array([2.9192599 , 4.18634938]),
#  array([2.89132269, 4.16264002]),
#  array([2.88131401, 4.16852862]),
#  array([2.92499962, 4.17030891]),
#  array([2.95513336, 4.14701385]),
#  array([2.89501921, 4.18499638]),
#  array([2.92249276, 4.16644447]),
#  array([2.91602685, 4.16793322]),
#  array([2.89307678, 4.11918536]),
#  array([2.92448325, 4.10000715]),
#  array([2.98111518, 4.03503035]),
#  array([3.04190886, 4.10558986]),
#  array([2.98241007, 4.20870505]),
#  array([2.99963936, 4.21426358]),
#  array([3.07076554, 4.10060575]),
#  array([3.08493175, 4.07885808]),
#  array([3.07021665, 4.09354377]),
#  array([3.04620874, 4.11766748]),
#  array([3.10152221, 4.12401545]),
#  array([3.07082652, 4.14012528]),
#  array([3.05178835, 4.12135679]),
#  array([3.12565955, 4.13757524]),
#  array([3.15434492, 4.17770348]),
#  array([3.14438345, 4.18244357]),
#  array([3.15853417, 4.19926556]),
#  array([3.13933466, 4.17201779]),
#  array([3.19139137, 4.1079817 ]),
#  array([3.19297523, 4.10664377]),
#  array([3.21392412, 4.12654522]),
#  array([3.23065881, 4.11521707]),
#  array([3.27843174, 4.12024314]),
#  array([3.24525684, 4.1645839 ]),
#  array([3.28508112, 4.22627796]),
#  array([3.29879409, 4.22692428]),
#  array([3.28786531, 4.24453595]),
#  array([3.28523728, 4.2429719 ]),
#  array([3.25564704, 4.16889111]),
#  array([3.25131748, 4.17234759]),
#  array([3.22974842, 4.20110507]),
#  array([3.22554126, 4.21058799]),
#  array([3.2381198 , 4.19696814]),
#  array([3.27641917, 4.17974135]),
#  array([3.2940953 , 4.19967939]),
#  array([3.28321267, 4.1953254 ]),
#  array([3.29898355, 4.20722137]),
#  array([3.32634575, 4.20097924]),
#  array([3.32772503, 4.19846235]),
#  array([3.29641819, 4.16247544]),
#  array([3.27187854, 4.14661708]),
#  array([3.21210018, 4.17244526]),
#  array([3.1769371 , 4.18265835]),
#  array([3.15987897, 4.18392523]),
#  array([3.13340024, 4.22190824]),
#  array([3.08272041, 4.28791829]),
#  array([3.0994745 , 4.29731382]),
#  array([3.05628484, 4.29077316]),
#  array([3.09725422, 4.27186096]),
#  array([3.11863526, 4.2725373 ]),
#  array([3.16688536, 4.28569421]),
#  array([3.14372588, 4.31586068]),
#  array([3.12294756, 4.28719764]),
#  array([3.14011938, 4.28763293]),
#  array([3.14221742, 4.28914209]),
#  array([3.11744496, 4.2664264 ]),
#  array([3.11839525, 4.26766302]),
#  array([3.08449739, 4.28374376]),
#  array([3.08550904, 4.28423295]),
#  array([3.0598274, 4.2359641]),
#  array([3.13289288, 4.18657757]),
#  array([3.18481029, 4.19362482]),
#  array([3.18372946, 4.19387821]),
#  array([3.15014363, 4.16666434]),
#  array([3.13884631, 4.16691691]),
#  array([3.13072752, 4.16867578]),
#  array([3.11603226, 4.18619431]),
#  array([3.09556691, 4.21701212]),
#  array([3.13677959, 4.25311282]),
#  array([3.14247751, 4.25374517]),
#  array([3.15073019, 4.24963825]),
#  array([3.21105935, 4.34659886]),
#  array([3.20735286, 4.34742963]),
#  array([3.13645324, 4.42283867]),
#  array([3.15680963, 4.43659162]),
#  array([3.21265586, 4.56536109]),
#  array([3.25103888, 4.46297043]),
#  array([3.26073718, 4.46939548]),
#  array([3.25926737, 4.46794232]),
#  array([3.27386114, 4.46794325]),
#  array([3.28413036, 4.46819323]),
#  array([3.30291012, 4.44696245]),
#  array([3.28748685, 4.44842085]),
#  array([3.25357938, 4.45463508]),
#  array([3.24212892, 4.45749036]),
#  array([3.26259062, 4.46101983]),
#  array([3.29260626, 4.47583955]),
#  array([3.30158665, 4.47194427]),
#  array([3.31079704, 4.47937392]),
#  array([3.34727643, 4.5102006 ]),
#  array([3.35059381, 4.50884095]),
#  array([3.34073379, 4.49654473]),
#  array([3.3704718 , 4.48233332]),
#  array([3.42329022, 4.46452275]),
#  array([3.46207897, 4.46861913]),
#  array([3.46567805, 4.46890369]),
#  array([3.43054535, 4.43488622]),
#  array([3.48180412, 4.37054943]),
#  array([3.52260284, 4.32725909]),
#  array([3.47044254, 4.21911538]),
#  array([3.42731854, 4.20910296]),
#  array([3.41702165, 4.21033207]),
#  array([3.37015019, 4.15455017]),
#  array([3.35037007, 4.15251551]),
#  array([3.3663561 , 4.16029013]),
#  array([3.32148266, 4.16176428]),
#  array([3.29533392, 4.15713031]),
#  array([3.28745938, 4.15980701]),
#  ...]
